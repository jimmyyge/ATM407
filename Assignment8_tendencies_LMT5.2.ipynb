# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
# <div style="float:right; width:300 px"><img src="https://github.com/brianmapes/ATM407/blob/master/images/LMT_5.4.png?raw=true" alt="Heating tendencies LMT_5.4 exercise image" style="height: 200px;"></div>
#
#
# <h1>Assignment 8: Heating rates in a midlatitude cyclone</h1>
# <h3>ATM 407, University of Miami</h3>
#
# * To use these Jupyter notebooks, you need to have installed all this:
# https://brianmapes.github.io/EarthCube-DRILSDOWN/ )
#
#
# ### Activities
# 1. <a href="#Exercise1">Some math about it</a>
# 1. <a href="#Exercise2">Load an IDV bundle</a>
# 1. <a href="#Exercise3">Answer the book's LMT_5.4 questions</a>
# 1. <a href="#Exercise4">Use LMT_5.4_MERRA_1979-2015 to make the same bundle for YOUR case.</a>
# 1. <a href="#Exercise5">Answer the mose interesting part for YOUR case.</a>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %% [markdown]
# ### Background
# Remember, for the test you will memorize and write the primitive equations:
# 1. Horizontal acceleration equation (F=ma):
# $$ \frac{d}{dt} \vec V_h = f \vec V_h \times \hat k  - \vec \nabla_p \Phi +\vec F_r  $$
# or, in component form,
# $$ \frac{du}{dt} = fv  - \frac{\partial \Phi}{\partial x} +F_{rx} $$
# $$ \frac{dv}{dt} = -fu - \frac{\partial \Phi}{\partial y} +F_{ry} $$
#
# 1. Vertical acceleration equation (aka Hydrostatic balance):
# $$ \frac {\partial \Phi}{\partial p} = - \alpha \equiv -\frac{1}{\rho} = \frac{RT}{p} = \frac{R\theta}{p} (\frac{T}{\theta})$$
# 1. Mass continuity:
# $$ 0 = \frac {\partial u}{\partial x} + \frac {\partial v}{\partial y}  + \frac {\partial \omega}{\partial p} $$
# 1. First Law of thermodynamics:
# $$ \frac {d \theta}{dt} = Q_\theta $$
# where $Q_\theta$, the heating rate in $\theta$ units, is related to dT/dt_{diabatic} = Q (in W/kg units) by:
# $$ Q_\theta = Q/C_p\frac{\theta}{T} $$
#
#
# #### For this exercise, let's focus on the First Law in the form used by atmosphere models (Eulerian grids).
#
# $$ \frac {\partial \theta}{\partial t} = -V \cdot \nabla \theta + Q_\theta  = Q_{dyn} + Q_{phys}$$
#
# Or, more to the point for digital atmospheric models with a finite timestep dt,
#
# $$ \theta_{future}(x,y,p) = \theta_{present} + dt \frac{(Q_{dyn} + Q_{phys} )} {C_p} \frac{\theta}{T}$$
#
# Save room in your brain for the concept of $Q_{ana}$, the *analysis tendency*, which is *the tendency required to make a model evolve in time as the world was observed to evolve in time.* (That is, *the sum of all errors in model estimates of Q{phys} and Q_{dyn} from all its derivatives and combinations of its state variables).
#
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise1"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 1</b>:
#      <ul>
#
# <li>**What is $\frac{\theta}{T}$ in the above casting of the equations? ** Show that it involves only the coordinate variable $p$.</li>
#
# <li>We can express $Q$ into the 3 physical forms of heat transfer (from fundamental physics): *radiation, conduction, convection, and chemical reaction.*</li>
#
# $$Q_{phys} = Q_{rad} +  Q_{surface} + Q_{turb} + Q_{chem}$$
#
# <li>**Explain in words how these map onto the column heating physics in atmosphere model:**</li>
#
# $$Q_{phys} = Q_{LW} +  Q_{SW} + Q_{SHF} + Q_{PBL \ diffusion} +Q_{gridscale \ cond-evap} + Q_{subgrid \ cumulus \ convection} +Q_{frictional \ dissipation}$$
#
# <li>**Explain how the profile of longwave radiation $Q_{LW}$ relates to the profile of cloudiness.**</li>
#
#     </ul>
# </div>

# %% [markdown]
# ## Exercise 1 Answer:
# ### First question bullet:
#
# $\frac{\theta}{T}$ =
#
#
# ### Second question (third bullet):
# 1. Q_LW is purely **radiative** (LW="longwave", the infrared radiation emitted by parts of the Earth system).
# 2. Q_SW is
# 3. Q_SHF is
# 4. Q_PBL is purely **turbulent** (heat transfer from one altitude to another carried by small or "subgrid" parcels of air).
# 5. Q_cond is
# 6. Q_cumulus is a mix of
# 7. Q_friction is arguably a version of **"conduction"**, as the kinetic energy of the wind gets turned into heat by the **physical contact** of molecules from micro-airmasses with different velocities.
#
# ### Third question (fourth bullet):
#
# Longwave heaing Q_LW is positive where more infrared photons arrive than leave. It is negative wherever more IR photons leave than arrive. Cloud effects can be understood using the concept that solid surfaces (both the Earth and cloud top and bottom) absorb all photons that strike them (no reflection), and emit more or less according to their local temperature as $\sigma T^4$. Since temperature T decreases with height in the troposphere, ... (complete the paragraph logically) ...

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise2"></a>
# ## Exercise 2: Find and load the LMT_5.4 bundle. Capture the storm image.

# %% [markdown]
# <div class="alert alert-info">
#     <b>Note</b>:
#      (If you like, you could do the Sandy version I made yesterday as a test, but it is bigger and slower to load.)
# </div>

# %%
# %reload_ext drilsdown
# Out:
# Starting IDV: /Applications/IDV_5.4u1/runIDV

# %%
# Your image 
#%makeImage
from IPython.display import Image
Image('E:\\atm407\\0.png')

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise3"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 3</b>:
#      <ul>
#       <li>**Answer the LMT_5.4 questions a-k, using image captures and Markdown cells to make this notebook a readable document you are proud of.**
#
#       </li>
#
#        <li>To do this, **copy the boldface question for each part from the text**, and then write your answers in normal text, so that a reader of this notebook gets a coherent narrative.
#
#       </li>
#
#     </ul>
# </div>

# %%
#%makeImage -caption example

Image('E:\\atm407\\a1.png')

# %% [markdown]
# <h2><center>1998-11-10 15Z</center></h2>

# %%
Image('E:\\atm407\\a2.png')

# %% [markdown]
# <h2><center>1998-11-10 18Z</center></h2>

# %%
Image('E:\\atm407\\a3.png')

# %% [markdown]
# <h2><center>1998-11-10 15Z</center></h2>

# %%
Image('E:\\atm407\\a4.png')

# %% [markdown]
# <h2><center>1998-11-10 18Z</center></h2>

# %% [markdown]
# ## Markdown answer for a):
#
#
# **Are the position of the cyclone and its fronts fairly well analyzed in the model fields? Does the model's rainfall (and condensation heating) match what you would infer from the satellite imagery? Capture an image indicating a discrepancy between the satellite observations and the model's depiction of the storm. What is your assessment of the general quality of the analysis?**
#
# The analysis seems to align rather well with the IR imagery, but there are a few disparities. The IR shows some of the cloud tops displaced very slightly ahead (i.e. east) of the largest MERRA prectot values. This is especially apparent in the "tail" of the cyclone. Furthermore, at the southern tip of the tail, the model shows precipitation occurring in a larger area than is suggested by the clouds alone.
#
# I also looked at the physical tendency (_phy_) for condensation heating (positive heating in red) and observed a similar displacement of the clouds ahead of the regions of heat release, which would indicate where condensation is taking place in the model. As with prectot, the model is showing heating taking place at the tip of the tail in a larger region than that simply covered by the clouds.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%makeImage -caption example

# %% [markdown]
# <img src="http://orca.rsmas.miami.edu/~jge/atm407/lab08/b1.gif">
# <h2><center>1998-11-10 15Z</center></h2>
# <img src="http://orca.rsmas.miami.edu/~jge/atm407/lab08/b2.gif">
# <h2><center>1998-11-10 18Z</center></h2>

# %% [markdown]
# ## Markdown answer for b):
#
#
# **Do some features in these displays correspond to each other? Which category of physical heating corresponds to MERRA's prectot? What main differences do you see in non-precipitating regions?**
#
# The precipitation and _phy_, which I looked at in Part (a), are the most closely related. As seen in the above images, the prectot could be imposed basically directly over the intense red areas. An patch of dry air near the center of the cyclone is also visible and matches up very well between the prectot and physical heating. In 18Z, there is a faint red shading outside of the precipitation, perhaps due to the daytime heating of the earth by the sun.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%makeImage -caption example

# %% [markdown]
# <img src="http://orca.rsmas.miami.edu/~jge/atm407/lab08/c1.gif">
# <h3><center>1998-11-10 15Z</center></h3>
# <img src="http://orca.rsmas.miami.edu/~jge/atm407/lab08/c2.gif">
# <h3><center>1998-11-10 18Z</center></h3>

# %% [markdown]
# ## Markdown answer for c):
#
# **Does [dthdt_dyn] also have features that correspond to the pattern of MERRA's prectot? Explain.**
#
# There is also an apparent correlation between prectot and dynamical tendency (_dyn_), indicated in blue, although in this case there were stronger differences between the two fields in non-precipitating areas. Although the certain features line up well such as the fronts and larger _dyn_ corresponding to more intense precip, _dyn_ is distributed toward much of the area of low pressure, rather than just where the clouds (and condensational heating) are, espcially adjacent and to the east of the center of the cyclone. Also worth mentioning is that at 18Z, there are more negative values of $d\theta/dt$ across the map compared to at 15Z.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption example
# Out:
# ERROR:root:Line magic function `%makeImage` not found.

# %% [markdown]
# ## Markdown answer for d):
#
# **Does this field [phy+dyn] have much correspondence with MERRA's prectot? Why or why not, in light of c) above?**
#
# **Loop between the two time steps. Using this logic, do the features in the net tendency phy+dyn explain the time evolution (motion and/or deepening) of the Z500 trough/cutoff? Explain, with annotated image captures as needed for clarity.**
#
# Ipsem lorem

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <img src="http://orca.rsmas.miami.edu/~jge/atm407/lab08/e1.gif">
# <h3><center>1998-11-10 15Z</center></h3>
# <img src="http://orca.rsmas.miami.edu/~jge/atm407/lab08/e2.gif">
# <h3><center>1998-11-10 18Z</center></h3>

# %% [markdown]
# ## Markdown answer for e):
#
# **Is this field [dthdt_ana] "large" in magnitude? Compared to what, and why is that the right comparison in light of these considerations? Does it have features that correspond to MERRA's prectot? What is your assessment of the general quality of the model's analysis and physics in depicting this storm?**
#
# The _ana_ field seems to be relatively small in magnitude, at least compared to the dynamical and physical fields. There also is very little, if any, correlation with MERRA's prectot. The only thing I can point out is that the center of the storm corresponds to a blue patch of _ana_. Since _ana_ is the difference in $d\theta/dt$ between observed and model values, I don't expect features to "appear" on _ana_, or else that would indicated some systematic error in the model. Based on the above analyses, I would say that the storm in general was modelled quite well.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%makeImage -caption example
Image('E:\\atm407\\f.png')

# %% [markdown]
# ## Markdown answer for f):
#
# **Activate the first two cross section displays: Temperature and Cloudiness. Where in the cyclone do you see low, middle, and high cloudiness? Is the analysis generally trustworthy in its vertical structure?**
#
# The lowest clouds are located slightly east of the center of the low, and they align with the region of stronger precipitation in the model, so they are perhaps associated with the cold front. The middle clouds to the west of the low appear to correspond to the intense precipitation close to the center. The high clouds are far to the east of the center of the cyclone and look to be associated with a thin band of precipitation.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%makeImage -caption example
Image('E:\\atm407\\g_lw.jpg')

# %%
Image('E:\\atm407\\g_sw.png')

# %% [markdown]
# ## Markdown answer for g):
#
# **Can you see the expected pattern of 1) heating at cloud bases, and 2) cooling space at cloud tops? Express the approximate magnitude of the heating in K per day, given that the displayed value is in K s-1. Which is more similar to the net radiative, the shortwave or longwave?**
#
# I observed that the regions that emit the most longwave radiation (first image) are the tops of the high clouds, while the cloud bases tend to absorb longwave energy. The shortwave is positive (sunlight is being absorbed) everywhere with highest values also at the cloud tops; the shortwave radiation interacts with the top of the atmosphere first, and so there is weaker absorption directly below the tall clouds. The longwave radiation is perhaps more similar to the net radiative transfer. I would estimate the average LW heating to be -3E-5 K/s and the SW heating to be +2E-5 K/s, so the net radiative transfer is roughly -1E-5 K/s * 86400 s/day = -0.864 K/day.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%makeImage -caption example
Image('E:\\atm407\\h_trb.png')

# %%
Image('E:\\atm407\\h_fri.png')

# %% [markdown]
# ## Markdown answer for h):
#
# **Where are [turbulent (dtdttrb) and frictional (dtdtfri) heating terms] active? Why? About how big are their largest magnitudes in K day-1?**
#
# The turbulent and frictional heating terms are strongest at the surface and boundary layer due to the wind's interaction with the ground creating friction and generating turbulent eddies. The highest values for both are 5E-5 K/s = ~4.32 K/day. For turbulence, these are positive values at the surface and negative directly aloft, whereas for friction, these values are purely positive but located in an extremely thin layer close to the surface, due to the effects of friction quickly dissipating with height.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%makeImage -caption example
Image('E:\\atm407\\i2.png')

# %% [markdown]
# <img src="http://orca.rsmas.miami.edu/~jge/atm407/lab08/i.gif">

# %% [markdown]
# ## Markdown answer for i):
#
# **How closely does dtdtmst correspond to the Cloudiness field? Where does dtdtmst have negative values? How can you understand those negative values in terms of moist processes (related to latent heat)?**
#
# The dtdtmst matches rather well with the cloudiness field, although there seems to be a significant amount of heating directly over the low clouds, which doesn't appear in the cloudiness field. The negative values occur directly below the clouds, which is a result of evaporation of precipitation as it falls.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%makeImage -caption example
Image('E:\\atm407\\j.jpg')

# %% [markdown]
# ## Markdown answer for j):
#
# **Capture an image, and annotate features on it which are contributed by 1) moist, 2) radiative, and 3) turbulent processes, synthesizing your findings above.**

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%makeImage -caption example
Image('E:\\atm407\\k.png')

# %% [markdown]
# ## Markdown answer for k):
#
# **Is the heat budget in this midlatitude cyclone primarily adiabatic? Show that the vertical integral over column mass is mainly contributed by the lower troposphere.**
#
# This display and especially the "saturated" values of dtdtdyn throughout the cross-section suggest that it is mostly dynamic processes that contribute to the midlatitude cyclone's heat budget. The vertical integral dyn matches up well at the dyn field.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise4"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 4</b>:
#      <ul>
#           <li>**Choose a storm case of your own. ** Maybe you did this last week. Choose carefully: you will revisit this as a project and perhaps make a Wikipedia page about it. If you like, choose a new one at this point.
#       </li>
#
#       <li>**Do the second optional exercise (loading LMT_5.4_MERRA_1979-2015 and moving the time and space box) for your case.**
#
#        <li>**Capture an image comparable to your favorite subsection above.**
#
#       </li>
#     </ul>
# </div>

# %%
# To use this feature, the IDV display must have its ID set to this name, in Properties. 
# %makeImage
# Out:
# ERROR:root:Line magic function `%makeImage` not found.

# %% [markdown]
# ## My case:
#
# #### I decided to study a storm that occurred (date and time, place), because (background info).
#
# The image above shows ...

# %%
# Wikipedia image
from IPython.display import Image
Image("an image URL goes here")

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# Upload your image to your GitHub area and put its URL into Blackboard.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">
